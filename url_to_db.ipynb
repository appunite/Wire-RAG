# %%
import aiohttp
import asyncio
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import nest_asyncio

# Apply the nest_asyncio patch to allow nested event loops in Jupyter
nest_asyncio.apply()

# Asynchronous URL fetching with retry logic
async def fetch_urls(url, session, retries=3):
    attempt = 0
    while attempt < retries:
        try:
            async with session.get(url, timeout=15) as response:
                if response.status != 200:
                    return set()  # Return an empty set if the page doesn't load
                content = await response.text()
                soup = BeautifulSoup(content, "html.parser")
                urls = set(
                    urljoin(url, link['href'])
                    for link in soup.find_all('a', href=True)
                    if urlparse(urljoin(url, link['href'])).scheme in ('http', 'https')
                )
                if attempt > 0:
                    print(f"Successfully fetched URL: {url} on attempt {attempt + 1}")
                return urls
        except (aiohttp.ClientError, asyncio.TimeoutError) as e:
            attempt += 1
            if attempt < retries:
                await asyncio.sleep(2 ** attempt)  # Exponential backoff
        except Exception as e:
            return set()

    print(f"Failed to fetch URL {url} after {retries} attempts.")
    return set()

# Check if URL should be allowed based on blacklist/whitelist mode
def is_url_allowed(url, black_list_data):
    url_list = black_list_data["list"]
    is_blacklist_mode = black_list_data["black_list"]
    
    parsed_url = urlparse(url)
    base_url = f"{parsed_url.scheme}://{parsed_url.netloc}"

    if is_blacklist_mode:
        # Blacklist mode: block URLs matching any blacklist entry
        for entry in url_list:
            entry_parsed = urlparse(entry)
            entry_base = f"{entry_parsed.scheme}://{entry_parsed.netloc}"
            if entry_base == base_url and url.startswith(entry):
                return False
            # Specifically check if the entry is a path that should be blocked
            if entry_parsed.netloc == parsed_url.netloc and urlparse(entry).path == parsed_url.path:
                return False
    else:
        # Whitelist mode: only allow URLs matching any whitelist entry
        return any(
            url.startswith(entry) or f"{urlparse(entry).scheme}://{urlparse(entry).netloc}" == base_url
            for entry in url_list
        )
    
    return True

# Asynchronous scraping with blacklist/whitelist and depth handling
async def scrape_urls(url, session, max_depth, current_depth=0, visited=None, black_list_data=None):
    if visited is None:
        visited = {}

    if current_depth > max_depth:
        return visited  # Stop recursion if depth limit exceeded

    if not is_url_allowed(url, black_list_data):
        return visited  # Skip URL if not allowed

    visited[url] = current_depth  # Store URL with its depth

    # Extract URLs from the current page
    urls = await fetch_urls(url, session)

    tasks = []
    for new_url in urls:
        if new_url not in visited and is_url_allowed(new_url, black_list_data):
            # Continue scraping at the next depth level if within depth limit
            if current_depth < max_depth:
                tasks.append(scrape_urls(new_url, session, max_depth, current_depth + 1, visited, black_list_data))

    # Await all the tasks concurrently
    await asyncio.gather(*tasks)
    return visited

# Entry point for asynchronous scraping
async def start_scraping(url, depth, black_list_data=None):
    async with aiohttp.ClientSession() as session:
        found_urls = await scrape_urls(url, session, depth, black_list_data=black_list_data)
    return found_urls

# %%
starting_url = "https://docs.wire.com"
depth_limit = 2
whitelist = {"list": ["https://docs.wire.com"], "black_list": False}

# Start scraping
scraped_urls = await start_scraping(starting_url, depth_limit, whitelist)

print("******************")
for url, depth in scraped_urls.items():
    print(f"Depth {depth}: {url}")
print(f"Total URLs found: {len(scraped_urls)}")
# Out:
# Successfully fetched URL: https://docs.wire.com/developer/developer/features.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/user/connection.html#connection-backend-internals on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/provisioning/scim-token.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/legalhold.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/config-options.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/processes.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/searchability.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/restund.html#what-is-it-used-for on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/api-client-perspective/index.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/user/rich-info.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/minio.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/team/legalhold.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/sft.html#prerequisites on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/single-sign-on/index.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/configure-federation.html#generate-and-configure-tls-server-and-client-certificates on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/federation/api.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/configure-federation.html#applying-all-configuration-changes on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/servant.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/restund.html#amount-of-users-and-file-descriptors on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/index.html#notes-for-developers on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/configure-federation.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/sft.html#establishing-a-call on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/searchability.html#searching-users-on-the-same-backend on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/overview.html#introduction on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/index.html#reference on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/configure-federation.html#dns-setup-for-federation on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/sft.html#federated-conference-calling on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/coding-conventions.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/oauth.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/user/activation.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/how-to.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/federation-api-conventions.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/rabbitmq-consumer.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/single-sign-on/understand/main.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/restund.html#load-balancing-and-high-availability on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/index.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/single-sign-on/adfs/main.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/team-feature-settings.html#mls-end-to-end-identity on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/team-feature-settings.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/overview.html#architecture-and-networking on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/associate/custom-backend-for-desktop-client.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/legalhold.html#installing-legal-hold on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/legalhold.html#introduction on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/federation-design-aspects.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/restund.html#introduction on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/minio.html#hurdles-from-the-trenches-disk-usage-statistics-directories-vs-disks on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/block-user-creation.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/federation/index.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/associate/sso-domain-redirect.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/classified-domains.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/cassandra-interaction.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/restund.html#architecture on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/api-client-perspective/swagger.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/team-feature-settings.html#rate-limiting-of-code-generation-requests on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/editor-setup.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/federation/fedcalls.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/user/connection.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/restund.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/upgrading.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/api-client-perspective/authentication.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/federation/architecture.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/sft.html#background on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/configure-federation.html#manually-test-that-your-configurations-work-as-expected on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/elastic-search.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/make-docker-and-qemu.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/scim/storage.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/dependencies.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/testing.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/linting.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/index.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/ on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/restund.html#network on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/changelog.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/elasticsearch-migration-2021-02-16.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/single-sign-on/centrify/main.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/building.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/pr-guidelines.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/team-feature-settings.html#ttl-for-nonces on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/overview.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/open-telemetry.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/crypto-libs.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/mls.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/single-sign-on/okta/main.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/user/registration.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/team-feature-settings.html#guest-links on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/legalhold.html#configuring-team-settings-to-use-legal-hold on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/large-conversations.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/understand/helm.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/developer/api-versioning.html on attempt 2
# Successfully fetched URL: https://docs.wire.com/developer/reference/conversation.html on attempt 2
# ******************
# Depth 0: https://docs.wire.com
# Depth 1: https://docs.wire.com/how-to/administrate/index.html
# Depth 1: https://docs.wire.com/how-to/install/index.html
# Depth 1: https://docs.wire.com/understand/index.html
# Depth 1: https://docs.wire.com/developer/index.html
# Depth 1: https://docs.wire.com/security-responses/index.html
# Depth 1: https://docs.wire.com#welcome-to-wire-s-documentation
# Depth 1: https://docs.wire.com/changelog/index.html
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#deleting-a-user-which-is-not-a-team-user
# Depth 2: https://docs.wire.com/how-to/administrate/etcd.html#how-to-see-cluster-health
# Depth 2: https://docs.wire.com/how-to/administrate/restund.html#how-to-restart-restund-without-having-downtime
# Depth 2: https://docs.wire.com/how-to/administrate/restund.html#how-to-check-which-restund-turn-servers-will-be-used-by-clients
# Depth 2: https://docs.wire.com/how-to/administrate/general-linux.html
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#how-to-obtain-logs-from-an-ios-client-to-investigate-issues
# Depth 2: https://docs.wire.com/how-to/administrate/etcd.html#troubleshooting
# Depth 2: https://docs.wire.com/how-to/administrate/minio.html#minio-maintenance
# Depth 2: https://docs.wire.com/how-to/administrate/kubernetes/certificate-renewal/index.html
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#how-to-retrieve-metric-values-manually
# Depth 2: https://docs.wire.com/how-to/administrate/cassandra.html#how-to-rolling-restart-a-cassandra-cluster
# Depth 2: https://docs.wire.com/how-to/administrate/index.html#administration
# Depth 2: https://docs.wire.com/how-to/administrate/elasticsearch.html#how-to-manually-look-into-what-is-stored-in-elasticsearch
# Depth 2: https://docs.wire.com/how-to/administrate/operations.html
# Depth 2: https://docs.wire.com/how-to/administrate/backup-disaster-recovery.html
# Depth 2: https://docs.wire.com/how-to/administrate/general-linux.html#how-can-i-see-if-my-tls-certificates-are-configured-the-way-i-expect
# Depth 2: https://docs.wire.com/how-to/administrate/elasticsearch.html#how-to-rolling-restart-an-elasticsearch-cluster
# Depth 2: https://docs.wire.com/how-to/administrate/minio.html#rotate-root-credentials
# Depth 2: https://docs.wire.com/how-to/administrate/restund.html#how-to-see-how-many-people-are-currently-connected-to-the-restund-server
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#searching-and-deleting-users-with-no-team
# Depth 2: https://docs.wire.com/how-to/install/post-install.html
# Depth 2: https://docs.wire.com/how-to/administrate/restund.html#how-to-renew-a-certificate-for-restund
# Depth 2: https://docs.wire.com/how-to/administrate/elasticsearch.html#troubleshooting
# Depth 2: https://docs.wire.com/how-to/administrate/elasticsearch.html#check-the-health-of-an-elasticsearch-node
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#manually-searching-for-users-in-cassandra
# Depth 2: https://docs.wire.com/how-to/administrate/elasticsearch.html
# Depth 2: https://docs.wire.com/how-to/administrate/backup-disaster-recovery.html#introduction
# Depth 2: https://docs.wire.com/how-to/administrate/restund.html#wire-server-configuration
# Depth 2: https://docs.wire.com/how-to/administrate/cassandra.html
# Depth 2: https://docs.wire.com/how-to/administrate/restund.html
# Depth 2: https://docs.wire.com/how-to/administrate/operations.html#reboot-procedures
# Depth 2: https://docs.wire.com/how-to/administrate/operations.html#understand-release-tags
# Depth 2: https://docs.wire.com/how-to/administrate/restund.html#rebooting-a-restund-node
# Depth 2: https://docs.wire.com/how-to/administrate/kubernetes/upgrade-cluster/index.html#troubleshooting-problems-arising-after-kubernetes-cluster-upgrades
# Depth 2: https://docs.wire.com/index.html
# Depth 2: https://docs.wire.com/how-to/administrate/etcd.html#how-to-rolling-restart-an-etcd-cluster
# Depth 2: https://docs.wire.com/how-to/administrate/etcd.html
# Depth 2: https://docs.wire.com/how-to/administrate/backup-disaster-recovery.html#recovery-procedure
# Depth 2: https://docs.wire.com/how-to/administrate/general-linux.html#how-can-i-see-if-my-tls-certificates-are-configured-the-way-i-expect-special-case-kubernetes-from-a-kubernetes-machine
# Depth 2: https://docs.wire.com/how-to/administrate/minio.html#check-the-health-of-a-minio-node
# Depth 2: https://docs.wire.com/how-to/administrate/cassandra.html#check-the-health-of-a-cassandra-node
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#identify-sso-users
# Depth 2: https://docs.wire.com/how-to/administrate/kubernetes/index.html
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#mass-invite-users-to-a-team
# Depth 2: https://docs.wire.com/how-to/administrate/etcd.html#backing-up-and-restoring
# Depth 2: https://docs.wire.com/how-to/administrate/kubernetes/upgrade-cluster/index.html
# Depth 2: https://docs.wire.com/how-to/administrate/backup-disaster-recovery.html#backing-up
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#create-a-team-using-the-scim-api
# Depth 2: https://docs.wire.com/how-to/administrate/elasticsearch.html#check-cluster-health
# Depth 2: https://docs.wire.com/how-to/administrate/minio.html#setting-up-interaction-with-minio
# Depth 2: https://docs.wire.com/how-to/administrate/operations.html#draining-pods-from-a-node-for-maintainance
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#reset-session-cookies
# Depth 2: https://docs.wire.com/how-to/administrate/kubernetes/restart-machines/index.html
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#how-to-obtain-logs-from-an-android-client-to-investigate-issues
# Depth 2: https://docs.wire.com/how-to/administrate/minio.html#should-you-be-using-minio
# Depth 2: https://docs.wire.com/how-to/administrate/general-linux.html#which-ports-and-network-interface-is-my-process-running-on
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#manual-search-on-elasticsearch-via-brig-recommended
# Depth 2: https://docs.wire.com/how-to/administrate/elasticsearch.html#list-cluster-nodes
# Depth 2: https://docs.wire.com/how-to/administrate/cassandra.html#how-to-inspect-tables-and-data-manually
# Depth 2: https://docs.wire.com/how-to/administrate/etcd.html#how-to-inspect-tables-and-data-manually
# Depth 2: https://docs.wire.com/how-to/administrate/minio.html
# Depth 2: https://docs.wire.com/how-to/administrate/operations.html#health-checks
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#how-to-manually-search-for-a-user-on-elasticsearh-directly-not-recommended
# Depth 2: https://docs.wire.com/how-to/administrate/restund.html#how-to-restart-restund-with-downtime
# Depth 2: https://docs.wire.com/how-to/administrate/users.html#how-to-manually-delete-a-user-from-elasticsearch-only
# Depth 2: https://docs.wire.com/how-to/administrate/users.html
# Depth 2: https://docs.wire.com/security-responses/2023-01-04_website_outage.html
# Depth 2: https://docs.wire.com/security-responses/2022-02-21_cve-2021-44521.html
# Depth 2: https://docs.wire.com/security-responses/index.html#security-responses
# Depth 2: https://docs.wire.com/security-responses/2022-11-01_openssl.html
# Depth 2: https://docs.wire.com/security-responses/2021-12-15_log4shell.html
# Depth 2: https://docs.wire.com/security-responses/2022-05-23_website_outage.html
# Depth 2: https://docs.wire.com/security-responses/2023-01-19_html_injection.html
# Depth 2: https://docs.wire.com/how-to/install/troubleshooting.html#problems-with-csp-on-the-web-based-applications-webapp-team-settings-account-pages
# Depth 2: https://docs.wire.com/how-to/install/troubleshooting.html#i-deployed-demo-smtp-but-i-m-not-receiving-any-verification-emails
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#preparing-to-install-charts-from-the-internet-with-helm
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#how-to-install-rabbitmq
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#introduction
# Depth 2: https://docs.wire.com/how-to/install/tls.html#ingress-traffic-wire-server
# Depth 2: https://docs.wire.com/how-to/install/tls.html
# Depth 2: https://docs.wire.com/how-to/install/aws-prod.html#using-real-aws-services-for-ses-sqs
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#controlling-the-speed-of-websocket-draining-during-cannon-pod-replacement
# Depth 2: https://docs.wire.com/how-to/install/version-requirements.html
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#load-balancer-on-cloud-provider
# Depth 2: https://docs.wire.com/how-to/install/helm.html#how-to-install-in-memory-databases-and-external-components
# Depth 2: https://docs.wire.com/how-to/install/web-app-settings.html#enforce-constant-bit-rate
# Depth 2: https://docs.wire.com/how-to/install/logging.html#nuking-it-all
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#marking-an-installation-as-self-hosted
# Depth 2: https://docs.wire.com/how-to/install/logging.html#status
# Depth 2: https://docs.wire.com/how-to/install/logging.html#debugging
# Depth 2: https://docs.wire.com/how-to/install/helm.html#prerequisites
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#persistence-and-high-availability
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#security
# Depth 2: https://docs.wire.com/how-to/install/logging.html#usage-after-installation
# Depth 2: https://docs.wire.com/how-to/install/troubleshooting.html#flaky-issues-with-cassandra-failed-quorums-etc
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#real-aws-services
# Depth 2: https://docs.wire.com/how-to/install/tls.html#sftd-ansible
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#dns-records
# Depth 2: https://docs.wire.com/how-to/install/prod-intro.html#getting-support
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#load-balancer-on-bare-metal-servers
# Depth 2: https://docs.wire.com/how-to/install/prod-intro.html#what-will-not-be-installed-by-default
# Depth 2: https://docs.wire.com/how-to/install/logging.html
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#rd-party-proxying
# Depth 2: https://docs.wire.com/how-to/install/kubernetes.html#how-to-set-up-your-hosts-ini-file
# Depth 2: https://docs.wire.com/how-to/install/troubleshooting.html#i-deployed-demo-smtp-and-i-want-to-skip-email-configuration-and-retrieve-verification-codes-directly
# Depth 2: https://docs.wire.com/how-to/install/ingress.html
# Depth 2: https://docs.wire.com/changelog/changelog.html
# Depth 2: https://docs.wire.com/how-to/install/troubleshooting.html#diagnosing-issues-with-installation-steps
# Depth 2: https://docs.wire.com/how-to/install/tls.html#restund-kubernetes
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#prerequisites
# Depth 2: https://docs.wire.com/how-to/install/helm.html
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#how-to-install-fake-smtp-email-services
# Depth 2: https://docs.wire.com/how-to/install/ansible-authentication.html#sudo-without-password
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html
# Depth 2: https://docs.wire.com/how-to/install/helm.html#how-to-install-wire-server-itself
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#smtp-server
# Depth 2: https://docs.wire.com/how-to/install/prod-intro.html#what-will-not-be-installed
# Depth 2: https://docs.wire.com/how-to/install/troubleshooting.html
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#metrics-logging
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#how-to-configure-real-smtp-email-services
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#s3-addressing-style
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#how-to-install-charts-that-provide-access-to-external-databases
# Depth 2: https://docs.wire.com/how-to/install/logging.html#prerequisites
# Depth 2: https://docs.wire.com/how-to/install/logging.html#post-install-kibana-setup
# Depth 2: https://docs.wire.com/how-to/install/planning.html
# Depth 2: https://docs.wire.com/how-to/install/planning.html#demo-installation-trying-functionality-out
# Depth 2: https://docs.wire.com/how-to/install/prod-intro.html
# Depth 2: https://docs.wire.com/how-to/install/helm.html#introduction
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#you-may-want
# Depth 2: https://docs.wire.com/how-to/install/tls.html#restund-ansible
# Depth 2: https://docs.wire.com/how-to/install/web-app-settings.html#enable-extra-entropy-only-on-windows
# Depth 2: https://docs.wire.com/how-to/install/planning.html#production-installation-persistent-data-high-availability
# Depth 2: https://docs.wire.com/how-to/install/ansible-VMs.html#assumptions
# Depth 2: https://docs.wire.com/how-to/install/sft.html#background
# Depth 2: https://docs.wire.com/how-to/install/monitoring.html#dashboards
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#routing-traffic-to-other-namespaces-via-nginz
# Depth 2: https://docs.wire.com/how-to/install/troubleshooting.html#obtaining-brig-logs-and-the-format-of-different-team-user-events
# Depth 2: https://docs.wire.com/how-to/install/kubernetes.html
# Depth 2: https://docs.wire.com/how-to/install/logging.html#installing-required-helm-charts
# Depth 2: https://docs.wire.com/how-to/install/troubleshooting.html#problems-with-ansible-and-python-versions
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#enable-push-notifications-using-the-public-appstore-playstore-mobile-wire-clients
# Depth 2: https://docs.wire.com/how-to/install/kubernetes.html#how-to-install-kubernetes
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#redirect-some-traffic-through-a-http-s-proxy
# Depth 2: https://docs.wire.com/how-to/install/post-install.html#logs-and-data-protection-checks
# Depth 2: https://docs.wire.com/how-to/install/ansible-VMs.html#preparing-to-run-ansible
# Depth 2: https://docs.wire.com/how-to/install/dependencies.html#alternative-installing-dependencies-using-direnv-and-nix
# Depth 2: https://docs.wire.com/how-to/install/troubleshooting.html#diagnosing-and-addressing-bad-network-disconnect-issues
# Depth 2: https://docs.wire.com/how-to/install/tls.html#egress-traffic-wire-server-federation
# Depth 2: https://docs.wire.com/how-to/install/logging.html#configuring-fluent-bit
# Depth 2: https://docs.wire.com/how-to/install/post-install.html#ntp-checks
# Depth 2: https://docs.wire.com/how-to/install/ansible-VMs.html#introduction
# Depth 2: https://docs.wire.com/how-to/install/web-app-settings.html
# Depth 2: https://docs.wire.com/how-to/install/web-app-settings.html#enforce-desktop-application-only
# Depth 2: https://docs.wire.com/how-to/install/tls.html#coturn-kubernetes
# Depth 2: https://docs.wire.com/how-to/install/ansible-VMs.html
# Depth 2: https://docs.wire.com/how-to/install/sft.html
# Depth 2: https://docs.wire.com/how-to/install/aws-prod.html#introduction
# Depth 2: https://docs.wire.com/how-to/install/aws-prod.html#using-real-aws-services-for-sns
# Depth 2: https://docs.wire.com/how-to/install/monitoring.html
# Depth 2: https://docs.wire.com/how-to/install/ingress.html#installing-on-bare-metal-without-dynamic-load-balancer-support
# Depth 2: https://docs.wire.com/how-to/install/restund.html#background
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#general-installation-notes
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#preparing-to-install-wire-server
# Depth 2: https://docs.wire.com/how-to/install/kubernetes.html#passwordless-authentication
# Depth 2: https://docs.wire.com/how-to/install/ansible-authentication.html#configuring-ssh-keys
# Depth 2: https://docs.wire.com/how-to/install/aws-prod.html#using-real-aws-services-for-s3
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#control-nginz-upstreams-routes-into-the-kubernetes-cluster
# Depth 2: https://docs.wire.com/how-to/install/web-app-settings.html#disable-media-plugins
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#configuring-authentication-cookie-throttling
# Depth 2: https://docs.wire.com/how-to/install/ansible-authentication.html#how-to-use-password-authentication-when-you-ssh-to-a-machine-with-ansible
# Depth 2: https://docs.wire.com/how-to/install/dependencies.html
# Depth 2: https://docs.wire.com/how-to/install/index.html#installation
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#separate-incoming-websocket-network-traffic-from-the-rest-of-the-https-traffic
# Depth 2: https://docs.wire.com/how-to/install/logging.html#introduction
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#how-to-install-fake-aws-services-for-sns-sqs
# Depth 2: https://docs.wire.com/how-to/install/troubleshooting.html#verifying-correct-deployment-of-dns-dns-troubleshooting
# Depth 2: https://docs.wire.com/how-to/install/infrastructure-configuration.html#i-have-a-team-larger-than-500-users
# Depth 2: https://docs.wire.com/how-to/install/helm.html#how-to-start-installing-charts-from-wire
# Depth 2: https://docs.wire.com/how-to/install/restund.html#installation-instructions
# Depth 2: https://docs.wire.com/how-to/install/aws-prod.html
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#watching-changes-as-they-happen
# Depth 2: https://docs.wire.com/how-to/install/helm.html#watching-changes-as-they-happen
# Depth 2: https://docs.wire.com/how-to/install/prod-intro.html#next-steps-for-high-available-production-installation
# Depth 2: https://docs.wire.com/how-to/install/restund.html
# Depth 2: https://docs.wire.com/how-to/install/tls.html#sftd-kubernetes
# Depth 2: https://docs.wire.com/how-to/install/ansible-VMs.html#running-ansible-to-install-software-on-your-machines
# Depth 2: https://docs.wire.com/how-to/install/version-requirements.html#persistence
# Depth 2: https://docs.wire.com/how-to/install/ingress.html#installing-in-a-cloud-like-environment
# Depth 2: https://docs.wire.com/how-to/install/helm-prod.html#how-to-install-wire-server-itself
# Depth 2: https://docs.wire.com/how-to/install/ansible-tinc.html
# Depth 2: https://docs.wire.com/how-to/install/ansible-authentication.html
# Depth 2: https://docs.wire.com/how-to/install/kubernetes.html#minio-setup
# Depth 2: https://docs.wire.com/how-to/install/prod-intro.html#what-will-be-installed-by-following-these-parts
# Depth 2: https://docs.wire.com/changelog/changelog.html#id413
# Depth 2: https://docs.wire.com/changelog/changelog.html#id349
# Depth 2: https://docs.wire.com/changelog/changelog.html#id419
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-42-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-38-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-41-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-12-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id380
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-108-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-29-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-9-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id415
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-37-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id374
# Depth 2: https://docs.wire.com/changelog/changelog.html#id458
# Depth 2: https://docs.wire.com/changelog/changelog.html#id324
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-110-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-5-4-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id430
# Depth 2: https://docs.wire.com/changelog/changelog.html#id185
# Depth 2: https://docs.wire.com/changelog/changelog.html#id339
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-23-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id391
# Depth 2: https://docs.wire.com/changelog/changelog.html#id446
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-101-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-2-0
# Depth 2: https://docs.wire.com/changelog/index.html#releases
# Depth 2: https://docs.wire.com/changelog/changelog.html#id465
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-121-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-30-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-18-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id334
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-114-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id424
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-40-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-11-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-112-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-36-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-117-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-14-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-19-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id462
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-104-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id365
# Depth 2: https://docs.wire.com/changelog/changelog.html#id454
# Depth 2: https://docs.wire.com/changelog/changelog.html#id369
# Depth 2: https://docs.wire.com/changelog/changelog.html#id370
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-3-30-6
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-26-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id306
# Depth 2: https://docs.wire.com/changelog/changelog.html#id315
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-34-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-95-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id319
# Depth 2: https://docs.wire.com/changelog/changelog.html#id356
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-99-12
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-125-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-21-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id401
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-111-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id411
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-6-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id377
# Depth 2: https://docs.wire.com/changelog/changelog.html#id468
# Depth 2: https://docs.wire.com/changelog/changelog.html#id344
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-31-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-105-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id387
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-122-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-8-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-124-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-13-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-24-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id406
# Depth 2: https://docs.wire.com/changelog/changelog.html#id259
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-113-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id360
# Depth 2: https://docs.wire.com/changelog/changelog.html#id435
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-115-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id352
# Depth 2: https://docs.wire.com/changelog/changelog.html#id438
# Depth 2: https://docs.wire.com/changelog/changelog.html#id442
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-116-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-22-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-118-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-95-18
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-5-3-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-10-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-109-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id329
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-97-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-107-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-0-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-25-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id450
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-5-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id459
# Depth 2: https://docs.wire.com/changelog/changelog.html#id300
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-4-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-43-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-35-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-7-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id310
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-4-39-0
# Depth 2: https://docs.wire.com/changelog/changelog.html#id383
# Depth 2: https://docs.wire.com/changelog/changelog.html#id396
# Depth 2: https://docs.wire.com/changelog/changelog.html#id273
# Depth 2: https://docs.wire.com/changelog/changelog.html#chart-release-2-102-0
# Depth 2: https://docs.wire.com/understand/federation/backend-communication.html
# Depth 2: https://docs.wire.com/understand/restund.html#discovery-and-establishing-a-call
# Depth 2: https://docs.wire.com/understand/associate/deeplink.html
# Depth 2: https://docs.wire.com/understand/configure-federation.html#configure-helm-charts-federator-and-ingress-and-webapp-subcharts
# Depth 2: https://docs.wire.com/understand/block-user-creation.html#in-the-webapp
# Depth 2: https://docs.wire.com/developer/reference/spar-braindump.html
# Depth 2: https://docs.wire.com/understand/restund.html#protocols-and-open-ports
# Depth 2: https://docs.wire.com/understand/single-sign-on/azure/main.html
# Depth 2: https://docs.wire.com/understand/associate/index.html
# Depth 2: https://docs.wire.com/understand/configure-federation.html#consequences-of-the-choice-of-a-backend-domain
# Depth 2: https://docs.wire.com/understand/team-feature-settings.html#mls-migration
# Depth 2: https://docs.wire.com/understand/searchability.html#searching-users-on-another-federated-backend
# Depth 2: https://docs.wire.com/understand/single-sign-on/generic-setup.html
# Depth 2: https://docs.wire.com/understand/single-sign-on/trouble-shooting.html
# Depth 2: https://docs.wire.com/understand/minio.html#minio-philosophy
# Depth 2: https://docs.wire.com/understand/sft.html#architecture
# Depth 2: https://docs.wire.com/understand/configure-federation.html#choose-a-backend-domain
# Depth 2: https://docs.wire.com/understand/restund.html#dns
# Depth 2: https://docs.wire.com/understand/configure-federation.html#summary-of-necessary-steps-to-configure-federation
# Depth 2: https://docs.wire.com/understand/team-feature-settings.html#nd-factor-password-challenge
# Depth 2: https://docs.wire.com/understand/sft.html
# Depth 2: https://docs.wire.com/understand/searchability.html#changing-the-settings-for-a-given-team
# Depth 2: https://docs.wire.com/understand/helm.html#overriding-helm-configuration-settings
# Depth 2: https://docs.wire.com/understand/associate/custom-certificates.html
# Depth 2: https://docs.wire.com/understand/block-user-creation.html#in-brig
# Depth 2: https://docs.wire.com/understand/crypto-libs.html
# Depth 2: https://docs.wire.com/understand/sft.html#multi-sft-architecture
# Depth 2: https://docs.wire.com/understand/legalhold.html
# Depth 2: https://docs.wire.com/understand/restund.html#what-is-it-used-for
# Depth 2: https://docs.wire.com/understand/single-sign-on/index.html
# Depth 2: https://docs.wire.com/understand/searchability.html
# Depth 2: https://docs.wire.com/understand/sft.html#prerequisites
# Depth 2: https://docs.wire.com/understand/minio.html
# Depth 2: https://docs.wire.com/understand/configure-federation.html#generate-and-configure-tls-server-and-client-certificates
# Depth 2: https://docs.wire.com/understand/configure-federation.html#applying-all-configuration-changes
# Depth 2: https://docs.wire.com/understand/federation/api.html
# Depth 2: https://docs.wire.com/understand/api-client-perspective/index.html
# Depth 2: https://docs.wire.com/understand/searchability.html#searching-users-on-the-same-backend
# Depth 2: https://docs.wire.com/understand/configure-federation.html
# Depth 2: https://docs.wire.com/understand/index.html#reference
# Depth 2: https://docs.wire.com/understand/restund.html#amount-of-users-and-file-descriptors
# Depth 2: https://docs.wire.com/understand/overview.html#introduction
# Depth 2: https://docs.wire.com/understand/team-feature-settings.html#mls-end-to-end-identity
# Depth 2: https://docs.wire.com/understand/federation/fedcalls.html
# Depth 2: https://docs.wire.com/understand/team-feature-settings.html#rate-limiting-of-code-generation-requests
# Depth 2: https://docs.wire.com/understand/restund.html
# Depth 2: https://docs.wire.com/understand/restund.html#architecture
# Depth 2: https://docs.wire.com/understand/sft.html#background
# Depth 2: https://docs.wire.com/understand/minio.html#hurdles-from-the-trenches-disk-usage-statistics-directories-vs-disks
# Depth 2: https://docs.wire.com/understand/legalhold.html#installing-legal-hold
# Depth 2: https://docs.wire.com/understand/associate/sso-domain-redirect.html
# Depth 2: https://docs.wire.com/understand/legalhold.html#configuring-team-settings-to-use-legal-hold
# Depth 2: https://docs.wire.com/understand/single-sign-on/okta/main.html
# Depth 2: https://docs.wire.com/understand/single-sign-on/centrify/main.html
# Depth 2: https://docs.wire.com/understand/overview.html
# Depth 2: https://docs.wire.com/understand/configure-federation.html#manually-test-that-your-configurations-work-as-expected
# Depth 2: https://docs.wire.com/understand/legalhold.html#introduction
# Depth 2: https://docs.wire.com/understand/federation/architecture.html
# Depth 2: https://docs.wire.com/understand/associate/custom-backend-for-desktop-client.html
# Depth 2: https://docs.wire.com/understand/team-feature-settings.html#guest-links
# Depth 2: https://docs.wire.com/understand/single-sign-on/adfs/main.html
# Depth 2: https://docs.wire.com/understand/overview.html#architecture-and-networking
# Depth 2: https://docs.wire.com/understand/restund.html#introduction
# Depth 2: https://docs.wire.com/understand/team-feature-settings.html
# Depth 2: https://docs.wire.com/understand/restund.html#load-balancing-and-high-availability
# Depth 2: https://docs.wire.com/understand/single-sign-on/understand/main.html
# Depth 2: https://docs.wire.com/understand/helm.html
# Depth 2: https://docs.wire.com/understand/api-client-perspective/swagger.html
# Depth 2: https://docs.wire.com/understand/federation/index.html
# Depth 2: https://docs.wire.com/understand/restund.html#network
# Depth 2: https://docs.wire.com/understand/team-feature-settings.html#ttl-for-nonces
# Depth 2: https://docs.wire.com/understand/block-user-creation.html
# Depth 2: https://docs.wire.com/understand/sft.html#federated-conference-calling
# Depth 2: https://docs.wire.com/understand/mls.html
# Depth 2: https://docs.wire.com/understand/api-client-perspective/authentication.html
# Depth 2: https://docs.wire.com/understand/classified-domains.html
# Depth 2: https://docs.wire.com/understand/configure-federation.html#dns-setup-for-federation
# Depth 2: https://docs.wire.com/understand/sft.html#establishing-a-call
# Depth 2: https://docs.wire.com/developer/reference/rabbitmq-consumer.html
# Depth 2: https://docs.wire.com/developer/reference/user/activation.html
# Depth 2: https://docs.wire.com/developer/developer/open-telemetry.html
# Depth 2: https://docs.wire.com/developer/developer/how-to.html
# Depth 2: https://docs.wire.com/developer/reference/oauth.html
# Depth 2: https://docs.wire.com/developer/developer/federation-design-aspects.html
# Depth 2: https://docs.wire.com/developer/developer/coding-conventions.html
# Depth 2: https://docs.wire.com/developer/reference/index.html
# Depth 2: https://docs.wire.com/developer/developer/pr-guidelines.html
# Depth 2: https://docs.wire.com/developer/developer/building.html
# Depth 2: https://docs.wire.com/developer/developer/features.html
# Depth 2: https://docs.wire.com/developer/reference/user/rich-info.html
# Depth 2: https://docs.wire.com/developer/reference/provisioning/scim-token.html
# Depth 2: https://docs.wire.com/developer/reference/user/connection.html#connection-backend-internals
# Depth 2: https://docs.wire.com/developer/developer/servant.html
# Depth 2: https://docs.wire.com/developer/reference/team/legalhold.html
# Depth 2: https://docs.wire.com/developer/developer/editor-setup.html
# Depth 2: https://docs.wire.com/developer/developer/federation-api-conventions.html
# Depth 2: https://docs.wire.com/developer/developer/cassandra-interaction.html
# Depth 2: https://docs.wire.com/developer/developer/processes.html
# Depth 2: https://docs.wire.com/developer/reference/config-options.html
# Depth 2: https://docs.wire.com/developer/reference/make-docker-and-qemu.html
# Depth 2: https://docs.wire.com/developer/developer/upgrading.html
# Depth 2: https://docs.wire.com/developer/reference/elasticsearch-migration-2021-02-16.html
# Depth 2: https://docs.wire.com/developer/reference/user/connection.html
# Depth 2: https://docs.wire.com/developer/developer/linting.html
# Depth 2: https://docs.wire.com/developer/developer/testing.html
# Depth 2: https://docs.wire.com/developer/developer/changelog.html
# Depth 2: https://docs.wire.com/developer/reference/user/registration.html
# Depth 2: https://docs.wire.com/developer/reference/conversation.html
# Depth 2: https://docs.wire.com/developer/developer/api-versioning.html
# Depth 2: https://docs.wire.com/developer/developer/index.html
# Depth 2: https://docs.wire.com/developer/developer/large-conversations.html
# Depth 2: https://docs.wire.com/developer/index.html#notes-for-developers
# Depth 2: https://docs.wire.com/
# Depth 2: https://docs.wire.com/developer/developer/dependencies.html
# Depth 2: https://docs.wire.com/developer/developer/scim/storage.html
# Depth 2: https://docs.wire.com/developer/reference/elastic-search.html
# Total URLs found: 426

# %%
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime

# Regular expression patterns for various date formats
date_patterns = [
    r'\b\d{4}-\d{2}-\d{2}\b',            # Matches YYYY-MM-DD (e.g., 2024-09-20)
    r'\b\d{4}/\d{2}/\d{2}\b',            # Matches YYYY/MM/DD (e.g., 2024/09/20)
    r'\b\d{2}-\d{2}-\d{4}\b',            # Matches MM-DD-YYYY (e.g., 09-20-2024)
    r'\b\d{2}/\d{2}/\d{4}\b',            # Matches MM/DD/YYYY (e.g., 09/20/2024)
    r'\b\d{2}-\d{2}-\d{4}\b',            # Matches DD-MM-YYYY (e.g., 20-09-2024)
    r'\b\d{2}/\d{2}/\d{4}\b',            # Matches DD/MM/YYYY (e.g., 20/09/2024)
    r'\b\d{1,2}\s+[A-Za-z]+\s+\d{4}\b',  # Matches 20 September 2024
    r'\b[A-Za-z]+\s+\d{1,2},\s+\d{4}\b', # Matches September 20, 2024
    r'\b\d{1,2}\s+[A-Za-z]{3}\s+\d{4}\b', # Matches 20 Sep 2024 (short month)
    r'\b[A-Za-z]{3}\s+\d{1,2},\s+\d{4}\b', # Matches Sep 20, 2024 (short month)
    r'\b\d{1,2}-[A-Za-z]{3}-\d{4}\b',    # Matches 20-Sep-2024 (short month)
    r'\b[A-Za-z]{3}-\d{1,2}-\d{4}\b',    # Matches Sep-20-2024 (short month)
    r'\b[A-Za-z]+,\s+\d{1,2}\s+[A-Za-z]+\s+\d{4}\b', # Matches Friday, 20 September 2024 (with weekday)
    r'\b[A-Za-z]+,\s+[A-Za-z]+\s+\d{1,2},\s+\d{4}\b', # Matches Friday, September 20, 2024 (with weekday)
    r'\b\d{4}\.\d{2}\.\d{2}\b',          # Matches YYYY.MM.DD (e.g., 2024.09.20)
    r'\b\d{2}\.\d{2}\.\d{4}\b',          # Matches DD.MM.YYYY (e.g., 20.09.2024)
    r'\b\d{4}\s+[A-Za-z]{3}\s+\d{1,2}\b',# Matches 2024 Sep 20
    r'\b\d{4}\s+[A-Za-z]+\s+\d{1,2}\b',  # Matches 2024 September 20
    r'\b\d{1,2}\s+[A-Za-z]+,\s+\d{4}\b', # Matches 20 September, 2024 (comma after day)
    r'\b[A-Za-z]+\s+\d{1,2}\s+\d{4}\b'   # Matches September 20 2024 (no comma)
]


def find_all_dates_with_regex(text):
    """Search for all date matches using regex patterns."""
    dates = []
    for pattern in date_patterns:
        matches = re.findall(pattern, text)  # Find all matches for the pattern
        dates.extend(matches)
    return dates

def parse_date(date_str):
    """Convert a date string to a datetime object, trying different formats."""
    date_formats = [
        '%Y-%m-%d',        # Format: 2024-09-20
        '%Y/%m/%d',        # Format: 2024/09/20
        '%m-%d-%Y',        # Format: 09-20-2024
        '%m/%d/%Y',        # Format: 09/20/2024
        '%d-%m-%Y',        # Format: 20-09-2024
        '%d/%m/%Y',        # Format: 20/09/2024
        '%d %B %Y',        # Format: 20 September 2024
        '%B %d, %Y',       # Format: September 20, 2024
        '%d %b %Y',        # Format: 20 Sep 2024 (short month)
        '%b %d, %Y',       # Format: Sep 20, 2024 (short month)
        '%d-%b-%Y',        # Format: 20-Sep-2024 (short month)
        '%b-%d-%Y',        # Format: Sep-20-2024 (short month)
        '%A, %d %B %Y',    # Format: Friday, 20 September 2024 (with weekday)
        '%A, %B %d, %Y',   # Format: Friday, September 20, 2024 (with weekday)
        '%Y.%m.%d',        # Format: 2024.09.20
        '%d.%m.%Y',        # Format: 20.09.2024 (European format)
        '%Y %b %d',        # Format: 2024 Sep 20 (short month)
        '%Y %B %d',        # Format: 2024 September 20
        '%d %B, %Y',       # Format: 20 September, 2024 (comma after day)
        '%B %d %Y'         # Format: September 20 2024 (no comma)
    ]
    
    for date_format in date_formats:
        try:
            return datetime.strptime(date_str, date_format)
        except ValueError:
            pass
    return None

def get_latest_date(dates):
    """Return the latest valid date from a list of date strings."""
    parsed_dates = [parse_date(date) for date in dates]
    # Filter out any dates that couldn't be parsed and return the latest one
    valid_dates = [d for d in parsed_dates if d is not None]
    return max(valid_dates).strftime('%Y-%m-%d') if valid_dates else "No valid date found"

def get_title_and_date(url):
    try:
        # Send an HTTP GET request to the URL
        response = requests.get(url)
        response.raise_for_status()  # Check for request errors

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract the title from the <title> tag
        title = soup.title.string if soup.title else "No title found"

        # Extract all text content to search for a date pattern
        text_content = soup.get_text(separator=' ', strip=True)

        # Use regex to find all dates in the page's text content
        dates = find_all_dates_with_regex(text_content)

        # Get the latest date found
        latest_date = get_latest_date(dates)

        return {'url': url, 'title': title, 'date': latest_date}

    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return {'url': url, 'title': "Error", 'date': "Error"}

# %%
results = [get_title_and_date(url) for url in scraped_urls]

# %%
print(results)
# Out:
# [{'url': 'https://docs.wire.com', 'title': 'Welcome to Wire’s documentation! — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/index.html', 'title': 'Administration — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/install/index.html', 'title': 'Installation — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/understand/index.html', 'title': 'Reference — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/developer/index.html', 'title': 'Notes for developers — Wire 0.0.4 documentation', 'date': '2021-02-16'}, {'url': 'https://docs.wire.com/security-responses/index.html', 'title': 'Security responses — Wire 0.0.4 documentation', 'date': '2023-01-19'}, {'url': 'https://docs.wire.com#welcome-to-wire-s-documentation', 'title': 'Welcome to Wire’s documentation! — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/changelog/index.html', 'title': 'Releases — Wire 0.0.4 documentation', 'date': '2024-07-09'}, {'url': 'https://docs.wire.com/how-to/administrate/users.html#deleting-a-user-which-is-not-a-team-user', 'title': 'Investigative tasks (e.g. searching for users as server admin) — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/etcd.html#how-to-see-cluster-health', 'title': 'Etcd — Wire 0.0.4 documentation', 'date': '2019-09-25'}, {'url': 'https://docs.wire.com/how-to/administrate/restund.html#how-to-restart-restund-without-having-downtime', 'title': 'Restund (TURN) — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/restund.html#how-to-check-which-restund-turn-servers-will-be-used-by-clients', 'title': 'Restund (TURN) — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/general-linux.html', 'title': 'General - Linux — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/users.html#how-to-obtain-logs-from-an-ios-client-to-investigate-issues', 'title': 'Investigative tasks (e.g. searching for users as server admin) — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/etcd.html#troubleshooting', 'title': 'Etcd — Wire 0.0.4 documentation', 'date': '2019-09-25'}, {'url': 'https://docs.wire.com/how-to/administrate/minio.html#minio-maintenance', 'title': 'Minio — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/kubernetes/certificate-renewal/index.html', 'title': 'Certificate renewal — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/users.html#how-to-retrieve-metric-values-manually', 'title': 'Investigative tasks (e.g. searching for users as server admin) — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/cassandra.html#how-to-rolling-restart-a-cassandra-cluster', 'title': 'Cassandra — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/index.html#administration', 'title': 'Administration — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/elasticsearch.html#how-to-manually-look-into-what-is-stored-in-elasticsearch', 'title': 'Elasticsearch — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/operations.html', 'title': 'Operational procedures — Wire 0.0.4 documentation', 'date': 'No valid date found'}, {'url': 'https://docs.wire.com/how-to/administrate/backup-disaster-recovery.html', 'title': 'Backup and disaster recovery — Wire 0.0.4 documentation', 'date': 'No valid ...

# %%
valid_date_count = sum(1 for result in results if result['date'] != "No valid date found")
print(f"Percentage of valid dates found: {valid_date_count / len(results):.2%}")
# Out:
# Percentage of valid dates found: 45.31%
